# %%
# Importing required libraries
import pandas as pd
from pycaret.regression import *
import seaborn as sns

# %%
# Loading the dataset
data = pd.read_excel("TG_T_CashValues_Rel (2).xlsx")
# Encoding the Gender column into numerical format
data['Gender'] = data['Gender'].map({'Male': 1, 'Female': 0})
# Displaying the first few rows of the processed data for verification
print(data.head())
# Out:
#    Gender  Age  Dur        PPV
# 0       1    0   20  15.198437
# 1       1    0   21  15.741015
# 2       1    0   22  16.267189
# 3       1    0   23  16.777448
# 4       1    0   24  17.272269

# %%
data.shape
# Out:
# (5270, 4)

# %%
data.dtypes
# Out:
# Gender      int64
# Age         int64
# Dur         int64
# PPV       float64
# dtype: object

# %%
data.duplicated().sum()
#عشان اشوف السطور المكررة اذا في مكرر بحذف
#بدي اشوف كود الحذف
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# Gender    0
# Age       0
# Dur       0
# PPV       0
# dtype: int64

# %%
data.isna().sum()
#done clean
# Out:
# Gender    0
# Age       0
# Dur       0
# PPV       0
# dtype: int64

# %%
sns.histplot(data=data,x="Age")
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(data=data,x="Dur")
# Out:
# <Axes: xlabel='Dur', ylabel='Count'>

# %%
sns.histplot(data=data,x="Gender")
# Out:
# <Axes: xlabel='Gender', ylabel='Count'>

# %%
sns.kdeplot(data=data,x="Age")
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.displot(data=data)

# %%
# Checking the correlation between features and the target variable
print(data.corr())
# Defining predictors (independent variables) and target variable
X = data[['Gender', 'Age', 'Dur']]  # Features
y = data['PPV']  # Target
# Out:
#               Gender           Age           Dur       PPV
# Gender  1.000000e+00 -5.839480e-16 -4.498407e-15 -0.019844
# Age    -5.839480e-16  1.000000e+00 -5.072426e-01 -0.565087
# Dur    -4.498407e-15 -5.072426e-01  1.000000e+00  0.978774
# PPV    -1.984397e-02 -5.650867e-01  9.787742e-01  1.000000

# %%
# Importing PyCaret for regression tasks
# Setting up the PyCaret environment
regression_setup = setup(
    data=data,
    target='PPV',  # Target variable
    numeric_features=['Age', 'Dur','Gender'],  # Numerical features
    normalize=True,  # Normalize data for better performance
    session_id=42  # Random seed for reproducibility
)
# Out:
# <style type="text/css">
# #T_73950_row8_col1, #T_73950_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_73950">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_73950_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_73950_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73950_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_73950_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_73950_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_73950_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_73950_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_73950_row1_col1" class="data row1 col1" >PPV</td>
#     </tr>
#     <tr>
#       <th id="T_73950_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_73950_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_73950_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_73950_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_73950_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_73950_row3_col1" class="data row3 col1" >(5270, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_73950_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_73950_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_73950_row4_col1" class="data row4 col1" >(5270, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_73950_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_73950_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_73950_row5_col1" class="data row5 col1" >(3688, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_73950_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_73950_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_73950_row6_col1" class="data row6 col1" >(1582, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_73950_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_73950_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_73950_row7_col1" class="data row7 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_73950_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_73950_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_73950_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_73950_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_73950_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_73950_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_73950_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_73950_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_73950_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_73950_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_73950_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_73950_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_73950_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_73950_row12_col0" class="data row12 col0" >Normalize</td>
#       <td id="T_73950_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_73950_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_73950_row13_col0" class="data row13 col0" >Normalize method</td>
#       <td id="T_73950_row13_col1" class="data row13 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_73950_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_73950_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_73950_row14_col1" class="data row14 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_73950_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_73950_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_73950_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_73950_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_73950_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_73950_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_73950_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_73950_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_73950_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_73950_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_73950_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_73950_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_73950_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_73950_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_73950_row19_col1" class="data row19 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_73950_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_73950_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_73950_row20_col1" class="data row20 col1" >8fff</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Comparing all regression models and selecting the best one
best_model = compare_models(sort="R2")
# Displaying the best model for analysis
print(best_model)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              00:10:38
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# <style type="text/css">
# #T_700f6 th {
#   text-align: left;
# }
# #T_700f6_row0_col0, #T_700f6_row1_col0, #T_700f6_row1_col1, #T_700f6_row1_col2, #T_700f6_row1_col3, #T_700f6_row1_col4, #T_700f6_row1_col5, #T_700f6_row1_col6, #T_700f6_row2_col0, #T_700f6_row2_col1, #T_700f6_row2_col2, #T_700f6_row2_col3, #T_700f6_row2_col4, #T_700f6_row2_col5, #T_700f6_row2_col6, #T_700f6_row3_col0, #T_700f6_row3_col1, #T_700f6_row3_col2, #T_700f6_row3_col3, #T_700f6_row3_col4, #T_700f6_row3_col5, #T_700f6_row3_col6, #T_700f6_row4_col0, #T_700f6_row4_col1, #T_700f6_row4_col2, #T_700f6_row4_col3, #T_700f6_row4_col4, #T_700f6_row4_col5, #T_700f6_row4_col6, #T_700f6_row5_col0, #T_700f6_row5_col1, #T_700f6_row5_col2, #T_700f6_row5_col3, #T_700f6_row5_col4, #T_700f6_row5_col5, #T_700f6_row5_col6, #T_700f6_row6_col0, #T_700f6_row6_col1, #T_700f6_row6_col2, #T_700f6_row6_col3, #T_700f6_row6_col4, #T_700f6_row6_col5, #T_700f6_row6_col6, #T_700f6_row7_col0, #T_700f6_row7_col1, #T_700f6_row7_col2, #T_700f6_row7_col3, #T_700f6_row7_col4, #T_700f6_row7_col5, #T_700f6_row7_col6, #T_700f6_row8_col0, #T_700f6_row8_col1, #T_700f6_row8_col2, #T_700f6_row8_col3, #T_700f6_row8_col4, #T_700f6_row8_col5, #T_700f6_row8_col6, #T_700f6_row9_col0, #T_700f6_row9_col1, #T_700f6_row9_col2, #T_700f6_row9_col3, #T_700f6_row9_col4, #T_700f6_row9_col5, #T_700f6_row9_col6, #T_700f6_row10_col0, #T_700f6_row10_col1, #T_700f6_row10_col2, #T_700f6_row10_col3, #T_700f6_row10_col4, #T_700f6_row10_col5, #T_700f6_row10_col6, #T_700f6_row11_col0, #T_700f6_row11_col1, #T_700f6_row11_col2, #T_700f6_row11_col3, #T_700f6_row11_col4, #T_700f6_row11_col5, #T_700f6_row11_col6, #T_700f6_row12_col0, #T_700f6_row12_col1, #T_700f6_row12_col2, #T_700f6_row12_col3, #T_700f6_row12_col4, #T_700f6_row12_col5, #T_700f6_row12_col6, #T_700f6_row13_col0, #T_700f6_row13_col1, #T_700f6_row13_col2, #T_700f6_row13_col3, #T_700f6_row13_col4, #T_700f6_row13_col5, #T_700f6_row13_col6, #T_700f6_row14_col0, #T_700f6_row14_col1, #T_700f6_row14_col2, #T_700f6_row14_col3, #T_700f6_row14_col4, #T_700f6_row14_col5, #T_700f6_row14_col6, #T_700f6_row15_col0, #T_700f6_row15_col1, #T_700f6_row15_col2, #T_700f6_row15_col3, #T_700f6_row15_col4, #T_700f6_row15_col5, #T_700f6_row15_col6, #T_700f6_row16_col0, #T_700f6_row16_col1, #T_700f6_row16_col2, #T_700f6_row16_col3, #T_700f6_row16_col4, #T_700f6_row16_col5, #T_700f6_row16_col6, #T_700f6_row17_col0, #T_700f6_row17_col1, #T_700f6_row17_col2, #T_700f6_row17_col3, #T_700f6_row17_col4, #T_700f6_row17_col5, #T_700f6_row17_col6 {
#   text-align: left;
# }
# #T_700f6_row0_col1, #T_700f6_row0_col2, #T_700f6_row0_col3, #T_700f6_row0_col4, #T_700f6_row0_col5, #T_700f6_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_700f6_row0_col7, #T_700f6_row1_col7, #T_700f6_row2_col7, #T_700f6_row3_col7, #T_700f6_row4_col7, #T_700f6_row5_col7, #T_700f6_row6_col7, #T_700f6_row9_col7, #T_700f6_row11_col7, #T_700f6_row12_col7, #T_700f6_row13_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_700f6_row7_col7, #T_700f6_row8_col7, #T_700f6_row10_col7, #T_700f6_row14_col7, #T_700f6_row15_col7, #T_700f6_row16_col7, #T_700f6_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_700f6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_700f6_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_700f6_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_700f6_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_700f6_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_700f6_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_700f6_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_700f6_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_700f6_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_700f6_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_700f6_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_700f6_row0_col1" class="data row0 col1" >0.0104</td>
#       <td id="T_700f6_row0_col2" class="data row0 col2" >0.0010</td>
#       <td id="T_700f6_row0_col3" class="data row0 col3" >0.0297</td>
#       <td id="T_700f6_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_700f6_row0_col5" class="data row0 col5" >0.0023</td>
#       <td id="T_700f6_row0_col6" class="data row0 col6" >0.0008</td>
#       <td id="T_700f6_row0_col7" class="data row0 col7" >0.0920</td>
#     </tr>
#     <tr>
#       <th id="T_700f6_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_700f6_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_700f6_row1_col1" class="data row1 col1" >0.0379</td>
#       <td id="T_700f6_row1_col2" class="data row1 col2" >0.0047</td>
#       <td id="T_700f6_row1_col3" class="data row1 col3" >0.0683</td>
#       <td id="T_700f6_row1_col4" class="data row1 col4" >0.9999</td>
#       <td id="T_700f6_row1_col5" class="data row1 col5" >0.0052</td>
#       <td id="T_700f6_row1_col6" class="data row1 col6" >0.0029</td>
#       <td id="T_700f6_row1_col7" class="data row1 col7" >0.1040</td>
#     </tr>
#     <tr>
#       <th id="T_700f6_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_700f6_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_700f6_row2_col1" class="data row2 col1" >0.0366</td>
#       <td id="T_700f6_row2_col2" class="data row2 col2" >0.0050</td>
#       <td id="T_700f6_row2_col3" class="data row2 col3" >0.0707</td>
#       <td id="T_700f6_row2_col4" class="data row2 col4" >0.9999</td>
#       <td id="T_700f6_row2_col5" class="data row2 col5" >0.0049</td>
#       <td id="T_700f6_row2_col6" class="data row2 col6" >0.0029</td>
#       <td id="T_700f6_row2_col7" class="data row2 col7" >0.1050</td>
#     </tr>
#     <tr>
#       <th id="T_700f6_level0_row3" class="row_heading level0 row3" >dt</th>
#       <td id="T_700f6_row3_col0" class="data row3 col0" >Decision Tree Regressor</td>
#       <td id="T_700f6_row3_col1" class="data row3 col1" >0.0537</td>
#       <td id="T_700f6_row3_col2" class="data row3 col2" >0.0102</td>
#       <td id="T_700f6_row3_col3" class="data row3 col3" >0.1007</td>
#       <td id="T_700f6_row3_col4" class="data row3 col4" >0.9998</td>
#       <td id="T_700f6_row3_col5" class="data row3 col5" >0.0067</td>
#       <td id="T_700f6_row3_col6" class="data row3 col6" >0.0037</td>
#       <td id="T_700f6_row3_col7" class="data row3 col7" >0.0140</td>
#     </tr>
#     <tr>
#       <th id="T_700f6_level0_row4" class="row_heading level0 row4" >gbr</th>
#       <td id="T_700f6_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_700f6_row4_col1" class="data row4 col1" >0.0814</td>
#       <td id="T_700f6_row4_col2" class="data row4 col2" >0.0186</td>
#       <td id="T_700f6_row4_col3" class="data row4 col3" >0.1358</td>
#       <td id="T_700f6_row4_col4" class="data row4 col4" >0.9996</td>
#       <td id="T_700f6_row4_col5" class="data row4 col5" >0.0119</td>
#       <td id="T_700f6_row4_col6" class="data row4 col6" >0.0084</td>
#       <td id="T_700f6_row4_col7" class="data row4 col7" >0.0460</td>
#     </tr>
#     <tr>
#       <th id="T_700f6_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_700f6_row5_col0" class="data row5 col0" >K Neighbors Regressor</td>
#       <td id="T_700f6_row5_col1" class="data row5 col1" >0.1239</td>
#       <td id="T_700f6_row5_col2" class="data row5 col2" >0.0312</td>
#       <td id="T_700f6_row5_col3" class="data row5 col3" >0.1765</td>
#       <td id="T_700f6_row5_col4" class="data row5 col4" >0.9994</td>
#       <td id="T_700f6_row5_col5" class="data row5 col5" >0.0451</td>
#       <td id="T_700f6_row5_col6" class="data row5 col6" >0.0273</td>
#       <td id="T_700f6_row5_col7" class="data row5 col7" >0.0180</td>
#     </tr>
#     <tr>
#       <th id="T_700f6_level
# ExtraTreesRegressor(n_jobs=-1, random_state=42)

# %%
# Comparing all regression models and selecting the best one
best_model = compare_models(sort="RMSE")
# Displaying the best model for analysis
print(best_model)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              00:12:53
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# <style type="text/css">
# #T_aeb73 th {
#   text-align: left;
# }
# #T_aeb73_row0_col0, #T_aeb73_row1_col0, #T_aeb73_row1_col1, #T_aeb73_row1_col2, #T_aeb73_row1_col3, #T_aeb73_row1_col4, #T_aeb73_row1_col5, #T_aeb73_row1_col6, #T_aeb73_row2_col0, #T_aeb73_row2_col1, #T_aeb73_row2_col2, #T_aeb73_row2_col3, #T_aeb73_row2_col4, #T_aeb73_row2_col5, #T_aeb73_row2_col6, #T_aeb73_row3_col0, #T_aeb73_row3_col1, #T_aeb73_row3_col2, #T_aeb73_row3_col3, #T_aeb73_row3_col4, #T_aeb73_row3_col5, #T_aeb73_row3_col6, #T_aeb73_row4_col0, #T_aeb73_row4_col1, #T_aeb73_row4_col2, #T_aeb73_row4_col3, #T_aeb73_row4_col4, #T_aeb73_row4_col5, #T_aeb73_row4_col6, #T_aeb73_row5_col0, #T_aeb73_row5_col1, #T_aeb73_row5_col2, #T_aeb73_row5_col3, #T_aeb73_row5_col4, #T_aeb73_row5_col5, #T_aeb73_row5_col6, #T_aeb73_row6_col0, #T_aeb73_row6_col1, #T_aeb73_row6_col2, #T_aeb73_row6_col3, #T_aeb73_row6_col4, #T_aeb73_row6_col5, #T_aeb73_row6_col6, #T_aeb73_row7_col0, #T_aeb73_row7_col1, #T_aeb73_row7_col2, #T_aeb73_row7_col3, #T_aeb73_row7_col4, #T_aeb73_row7_col5, #T_aeb73_row7_col6, #T_aeb73_row8_col0, #T_aeb73_row8_col1, #T_aeb73_row8_col2, #T_aeb73_row8_col3, #T_aeb73_row8_col4, #T_aeb73_row8_col5, #T_aeb73_row8_col6, #T_aeb73_row9_col0, #T_aeb73_row9_col1, #T_aeb73_row9_col2, #T_aeb73_row9_col3, #T_aeb73_row9_col4, #T_aeb73_row9_col5, #T_aeb73_row9_col6, #T_aeb73_row10_col0, #T_aeb73_row10_col1, #T_aeb73_row10_col2, #T_aeb73_row10_col3, #T_aeb73_row10_col4, #T_aeb73_row10_col5, #T_aeb73_row10_col6, #T_aeb73_row11_col0, #T_aeb73_row11_col1, #T_aeb73_row11_col2, #T_aeb73_row11_col3, #T_aeb73_row11_col4, #T_aeb73_row11_col5, #T_aeb73_row11_col6, #T_aeb73_row12_col0, #T_aeb73_row12_col1, #T_aeb73_row12_col2, #T_aeb73_row12_col3, #T_aeb73_row12_col4, #T_aeb73_row12_col5, #T_aeb73_row12_col6, #T_aeb73_row13_col0, #T_aeb73_row13_col1, #T_aeb73_row13_col2, #T_aeb73_row13_col3, #T_aeb73_row13_col4, #T_aeb73_row13_col5, #T_aeb73_row13_col6, #T_aeb73_row14_col0, #T_aeb73_row14_col1, #T_aeb73_row14_col2, #T_aeb73_row14_col3, #T_aeb73_row14_col4, #T_aeb73_row14_col5, #T_aeb73_row14_col6, #T_aeb73_row15_col0, #T_aeb73_row15_col1, #T_aeb73_row15_col2, #T_aeb73_row15_col3, #T_aeb73_row15_col4, #T_aeb73_row15_col5, #T_aeb73_row15_col6, #T_aeb73_row16_col0, #T_aeb73_row16_col1, #T_aeb73_row16_col2, #T_aeb73_row16_col3, #T_aeb73_row16_col4, #T_aeb73_row16_col5, #T_aeb73_row16_col6, #T_aeb73_row17_col0, #T_aeb73_row17_col1, #T_aeb73_row17_col2, #T_aeb73_row17_col3, #T_aeb73_row17_col4, #T_aeb73_row17_col5, #T_aeb73_row17_col6 {
#   text-align: left;
# }
# #T_aeb73_row0_col1, #T_aeb73_row0_col2, #T_aeb73_row0_col3, #T_aeb73_row0_col4, #T_aeb73_row0_col5, #T_aeb73_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_aeb73_row0_col7, #T_aeb73_row1_col7, #T_aeb73_row2_col7, #T_aeb73_row3_col7, #T_aeb73_row4_col7, #T_aeb73_row5_col7, #T_aeb73_row6_col7, #T_aeb73_row7_col7, #T_aeb73_row8_col7, #T_aeb73_row9_col7, #T_aeb73_row11_col7, #T_aeb73_row12_col7, #T_aeb73_row13_col7, #T_aeb73_row14_col7, #T_aeb73_row15_col7, #T_aeb73_row16_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_aeb73_row10_col7, #T_aeb73_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_aeb73">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aeb73_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_aeb73_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_aeb73_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_aeb73_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_aeb73_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_aeb73_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_aeb73_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_aeb73_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aeb73_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_aeb73_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_aeb73_row0_col1" class="data row0 col1" >0.0104</td>
#       <td id="T_aeb73_row0_col2" class="data row0 col2" >0.0010</td>
#       <td id="T_aeb73_row0_col3" class="data row0 col3" >0.0297</td>
#       <td id="T_aeb73_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_aeb73_row0_col5" class="data row0 col5" >0.0023</td>
#       <td id="T_aeb73_row0_col6" class="data row0 col6" >0.0008</td>
#       <td id="T_aeb73_row0_col7" class="data row0 col7" >0.0940</td>
#     </tr>
#     <tr>
#       <th id="T_aeb73_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_aeb73_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_aeb73_row1_col1" class="data row1 col1" >0.0379</td>
#       <td id="T_aeb73_row1_col2" class="data row1 col2" >0.0047</td>
#       <td id="T_aeb73_row1_col3" class="data row1 col3" >0.0683</td>
#       <td id="T_aeb73_row1_col4" class="data row1 col4" >0.9999</td>
#       <td id="T_aeb73_row1_col5" class="data row1 col5" >0.0052</td>
#       <td id="T_aeb73_row1_col6" class="data row1 col6" >0.0029</td>
#       <td id="T_aeb73_row1_col7" class="data row1 col7" >0.1050</td>
#     </tr>
#     <tr>
#       <th id="T_aeb73_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_aeb73_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_aeb73_row2_col1" class="data row2 col1" >0.0366</td>
#       <td id="T_aeb73_row2_col2" class="data row2 col2" >0.0050</td>
#       <td id="T_aeb73_row2_col3" class="data row2 col3" >0.0707</td>
#       <td id="T_aeb73_row2_col4" class="data row2 col4" >0.9999</td>
#       <td id="T_aeb73_row2_col5" class="data row2 col5" >0.0049</td>
#       <td id="T_aeb73_row2_col6" class="data row2 col6" >0.0029</td>
#       <td id="T_aeb73_row2_col7" class="data row2 col7" >0.1380</td>
#     </tr>
#     <tr>
#       <th id="T_aeb73_level0_row3" class="row_heading level0 row3" >dt</th>
#       <td id="T_aeb73_row3_col0" class="data row3 col0" >Decision Tree Regressor</td>
#       <td id="T_aeb73_row3_col1" class="data row3 col1" >0.0537</td>
#       <td id="T_aeb73_row3_col2" class="data row3 col2" >0.0102</td>
#       <td id="T_aeb73_row3_col3" class="data row3 col3" >0.1007</td>
#       <td id="T_aeb73_row3_col4" class="data row3 col4" >0.9998</td>
#       <td id="T_aeb73_row3_col5" class="data row3 col5" >0.0067</td>
#       <td id="T_aeb73_row3_col6" class="data row3 col6" >0.0037</td>
#       <td id="T_aeb73_row3_col7" class="data row3 col7" >0.0140</td>
#     </tr>
#     <tr>
#       <th id="T_aeb73_level0_row4" class="row_heading level0 row4" >gbr</th>
#       <td id="T_aeb73_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_aeb73_row4_col1" class="data row4 col1" >0.0814</td>
#       <td id="T_aeb73_row4_col2" class="data row4 col2" >0.0186</td>
#       <td id="T_aeb73_row4_col3" class="data row4 col3" >0.1358</td>
#       <td id="T_aeb73_row4_col4" class="data row4 col4" >0.9996</td>
#       <td id="T_aeb73_row4_col5" class="data row4 col5" >0.0119</td>
#       <td id="T_aeb73_row4_col6" class="data row4 col6" >0.0084</td>
#       <td id="T_aeb73_row4_col7" class="data row4 col7" >0.0470</td>
#     </tr>
#     <tr>
#       <th id="T_aeb73_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_aeb73_row5_col0" class="data row5 col0" >K Neighbors Regressor</td>
#       <td id="T_aeb73_row5_col1" class="data row5 col1" >0.1239</td>
#       <td id="T_aeb73_row5_col2" class="data row5 col2" >0.0312</td>
#       <td id="T_aeb73_row5_col3" class="data row5 col3" >0.1765</td>
#       <td id="T_aeb73_row5_col4" class="data row5 col4" >0.9994</td>
#       <td id="T_aeb73_row5_col5" class="data row5 col5" >0.0451</td>
#       <td id="T_aeb73_row5_col6" class="data row5 col6" >0.0273</td>
#       <td id="T_aeb73_row5_col7" class="data row5 col7" >0.0180</td>
#     </tr>
#     <tr>
#       <th id="T_aeb73_level
# ExtraTreesRegressor(n_jobs=-1, random_state=42)

# %%
# Tuning the best model's hyperparameters
tuned_model = tune_model(best_model)
# Displaying the tuned model for verification
print(tuned_model)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              22:33:52
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# <style type="text/css">
# #T_8eaa8_row10_col0, #T_8eaa8_row10_col1, #T_8eaa8_row10_col2, #T_8eaa8_row10_col3, #T_8eaa8_row10_col4, #T_8eaa8_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_8eaa8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8eaa8_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_8eaa8_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_8eaa8_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_8eaa8_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_8eaa8_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_8eaa8_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8eaa8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8eaa8_row0_col0" class="data row0 col0" >0.3664</td>
#       <td id="T_8eaa8_row0_col1" class="data row0 col1" >0.2582</td>
#       <td id="T_8eaa8_row0_col2" class="data row0 col2" >0.5081</td>
#       <td id="T_8eaa8_row0_col3" class="data row0 col3" >0.9948</td>
#       <td id="T_8eaa8_row0_col4" class="data row0 col4" >0.0528</td>
#       <td id="T_8eaa8_row0_col5" class="data row0 col5" >0.0453</td>
#     </tr>
#     <tr>
#       <th id="T_8eaa8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8eaa8_row1_col0" class="data row1 col0" >0.3668</td>
#       <td id="T_8eaa8_row1_col1" class="data row1 col1" >0.2271</td>
#       <td id="T_8eaa8_row1_col2" class="data row1 col2" >0.4766</td>
#       <td id="T_8eaa8_row1_col3" class="data row1 col3" >0.9950</td>
#       <td id="T_8eaa8_row1_col4" class="data row1 col4" >0.0450</td>
#       <td id="T_8eaa8_row1_col5" class="data row1 col5" >0.0376</td>
#     </tr>
#     <tr>
#       <th id="T_8eaa8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8eaa8_row2_col0" class="data row2 col0" >0.3820</td>
#       <td id="T_8eaa8_row2_col1" class="data row2 col1" >0.2859</td>
#       <td id="T_8eaa8_row2_col2" class="data row2 col2" >0.5347</td>
#       <td id="T_8eaa8_row2_col3" class="data row2 col3" >0.9938</td>
#       <td id="T_8eaa8_row2_col4" class="data row2 col4" >0.0462</td>
#       <td id="T_8eaa8_row2_col5" class="data row2 col5" >0.0376</td>
#     </tr>
#     <tr>
#       <th id="T_8eaa8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8eaa8_row3_col0" class="data row3 col0" >0.4457</td>
#       <td id="T_8eaa8_row3_col1" class="data row3 col1" >0.3355</td>
#       <td id="T_8eaa8_row3_col2" class="data row3 col2" >0.5792</td>
#       <td id="T_8eaa8_row3_col3" class="data row3 col3" >0.9933</td>
#       <td id="T_8eaa8_row3_col4" class="data row3 col4" >0.0566</td>
#       <td id="T_8eaa8_row3_col5" class="data row3 col5" >0.0488</td>
#     </tr>
#     <tr>
#       <th id="T_8eaa8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8eaa8_row4_col0" class="data row4 col0" >0.3730</td>
#       <td id="T_8eaa8_row4_col1" class="data row4 col1" >0.2379</td>
#       <td id="T_8eaa8_row4_col2" class="data row4 col2" >0.4877</td>
#       <td id="T_8eaa8_row4_col3" class="data row4 col3" >0.9958</td>
#       <td id="T_8eaa8_row4_col4" class="data row4 col4" >0.0513</td>
#       <td id="T_8eaa8_row4_col5" class="data row4 col5" >0.0433</td>
#     </tr>
#     <tr>
#       <th id="T_8eaa8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8eaa8_row5_col0" class="data row5 col0" >0.3848</td>
#       <td id="T_8eaa8_row5_col1" class="data row5 col1" >0.2857</td>
#       <td id="T_8eaa8_row5_col2" class="data row5 col2" >0.5345</td>
#       <td id="T_8eaa8_row5_col3" class="data row5 col3" >0.9940</td>
#       <td id="T_8eaa8_row5_col4" class="data row5 col4" >0.0518</td>
#       <td id="T_8eaa8_row5_col5" class="data row5 col5" >0.0435</td>
#     </tr>
#     <tr>
#       <th id="T_8eaa8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8eaa8_row6_col0" class="data row6 col0" >0.3962</td>
#       <td id="T_8eaa8_row6_col1" class="data row6 col1" >0.2866</td>
#       <td id="T_8eaa8_row6_col2" class="data row6 col2" >0.5353</td>
#       <td id="T_8eaa8_row6_col3" class="data row6 col3" >0.9941</td>
#       <td id="T_8eaa8_row6_col4" class="data row6 col4" >0.0525</td>
#       <td id="T_8eaa8_row6_col5" class="data row6 col5" >0.0440</td>
#     </tr>
#     <tr>
#       <th id="T_8eaa8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8eaa8_row7_col0" class="data row7 col0" >0.3931</td>
#       <td id="T_8eaa8_row7_col1" class="data row7 col1" >0.2683</td>
#       <td id="T_8eaa8_row7_col2" class="data row7 col2" >0.5180</td>
#       <td id="T_8eaa8_row7_col3" class="data row7 col3" >0.9948</td>
#       <td id="T_8eaa8_row7_col4" class="data row7 col4" >0.0553</td>
#       <td id="T_8eaa8_row7_col5" class="data row7 col5" >0.0479</td>
#     </tr>
#     <tr>
#       <th id="T_8eaa8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8eaa8_row8_col0" class="data row8 col0" >0.3663</td>
#       <td id="T_8eaa8_row8_col1" class="data row8 col1" >0.2303</td>
#       <td id="T_8eaa8_row8_col2" class="data row8 col2" >0.4799</td>
#       <td id="T_8eaa8_row8_col3" class="data row8 col3" >0.9953</td>
#       <td id="T_8eaa8_row8_col4" class="data row8 col4" >0.0468</td>
#       <td id="T_8eaa8_row8_col5" class="data row8 col5" >0.0401</td>
#     </tr>
#     <tr>
#       <th id="T_8eaa8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8eaa8_row9_col0" class="data row9 col0" >0.3814</td>
#       <td id="T_8eaa8_row9_col1" class="data row9 col1" >0.2405</td>
#       <td id="T_8eaa8_row9_col2" class="data row9 col2" >0.4905</td>
#       <td id="T_8eaa8_row9_col3" class="data row9 col3" >0.9957</td>
#       <td id="T_8eaa8_row9_col4" class="data row9 col4" >0.0563</td>
#       <td id="T_8eaa8_row9_col5" class="data row9 col5" >0.0488</td>
#     </tr>
#     <tr>
#       <th id="T_8eaa8_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_8eaa8_row10_col0" class="data row10 col0" >0.3856</td>
#       <td id="T_8eaa8_row10_col1" class="data row10 col1" >0.2656</td>
#       <td id="T_8eaa8_row10_col2" class="data row10 col2" >0.5144</td>
#       <td id="T_8eaa8_row10_col3" class="data row10 col3" >0.9946</td>
#       <td id="T_8eaa8_row10_col4" class="data row10 col4" >0.0514</td>
#       <td id="T_8eaa8_row10_col5" class="data row10 col5" >0.0437</td>
#     </tr>
#     <tr>
#       <th id="T_8eaa8_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_8eaa8_row11_col0" class="data row11 col0" >0.0225</td>
#       <td id="T_8eaa8_row11_col1" class="data row11 col1" >0.0321</td>
#       <td id="T_8eaa8_row11_col2" class="data row11 col2" >0.0307</td>
#       <td id="T_8eaa8_row11_col3" class="data row11 col3" >0.0008</td>
#       <td id="T_8eaa8_row11_col4" class="data row11 col4" >0.0040</td>
#       <td id="T_8eaa8_row11_col5" class="data row11 col5" >0.0040</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# ExtraTreesRegressor(n_jobs=-1, random_state=42)

# %%
# تنفيذ Cross-Validation وتقييم النموذج باستخدام مقاييس مختلفة
evaluate_model(tuned_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# تنفيذ Cross-Validation وتقييم النموذج باستخدام مقاييس مختلفة
evaluate_model(tuned_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
save_model(tuned_model,'best_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['Age', 'Dur', 'Gender'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=[],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('normalize', TransformerWrapper(transformer=StandardScaler())),
#                  ('trained_model',
#                   ExtraTreesRegressor(n_jobs=-1, random_state=42))]),
#  'best_model.pkl')
